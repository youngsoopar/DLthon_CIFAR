# %% [markdown]
# # 초기모델

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 데이터증강을 시도하지 않은 초기 모델의 test 데이터의 정확도는 약 81%로 나왔다.

# %% [markdown]
# # 1번째 데이터 증강
# 사용된 데이터 증강 : 좌우반전, 회전, 대비조절, 밝기조절

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 학습루프 및 정확도 확인

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
# ![image.png](attachment:image.png)

# %% [markdown]
# 초기 모델보다 정확도가 약 10% 높아진것을 확인할 수 있다. 정확도를 보다 높이기 위해 다른 증강기법을 사용해보자

# %% [markdown]
# # 컨퓨전 매트릭스 & 학습 확인

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 2번째 데이터 증강
# 사용된 데이터 증강 : 좌우반전, 상하반전, 회전, 대비조절

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 학습루프 및 정확도 확인

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 1번째 증강 데이터보다 정확도가 떨어진것을 확인할 수 있다. 유의미한 결과를 만들지 않았기 때문에 더 많은 기법을 추가해보자

# %% [markdown]
# # 컨퓨전 매트릭스 & 학습 확인

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 3번째 데이터 증강
# 사용된 데이터 증강 : 좌우반전, 상하반전, 회전, 대비조절, 밝기조절, 색조조절, 채도조절

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 학습루프 및 정확도 확인

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 2번째 증강 데이터에 밝기와 색조 채도를 랜덤으로 조절하게 해보았다. 다양한 데이터가 생기기 때문에 정확도가 오를 것으로 생각했다. 하지만 1번째 데이터와 비슷하지만 조금 떨어지는 것을 확인할 수 있었다. 증강기법이 많아진다고 해서 정확도가 무조건 오르는 것은 아니다.

# %% [markdown]
# # 컨퓨전 매트릭스 & 학습 확인

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 4번째 데이터 증강
# 사용된 데이터 증강 : 좌우반전, 상하반전, 회전, 대비조절, 밝기조절, 색조조절, 채도조절, 이미지의 JPEG 압축 품질을 랜덤하게 조절

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 학습루프 및 정확도 확인

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# 3번째 증강 데이터에 이미지의 압축품질을 랜덤하게 조절하는 증강기법을 사용해 봤다. 품질을 조절하는 거라 train 정확도는 떨어지지만 일반화가 잘 되어 평가 정확도가 오를 것이란 발칙한 상상을 해보았다. 하지만 앞에서 해봤던것 보다 오히려 정확도가 떨어졌다.

# %% [markdown]
# # 컨퓨전 매트릭스 & 학습 확인

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 결과
# 데이터 증강을 통해서 초기 모델보다 정확도가 높은 값을 구할 수 있었다. 하지만 데이터 증강이 많으면 많을수록 오히려 과적합이 발생하여 정확도가 떨어지는 것을 확인 할 수 있었다.

# %% [markdown]
# # 느낀점
# 매개 변수 선택 어려움이 너무 어려웠다. 그리고 증강기법의 개수 보다는 적당하게 버무리는 것이 좋다는 걸 깨달았다. <br>
# -진영님 느낀점
