# %%
# !nvidia-smi
# Out:
# Wed Aug 30 02:54:21 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.182.03   Driver Version: 470.182.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    10W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# 데이터 로딩 및 전처리
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# 클래스 이름 정의
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# BasicBlock 정의
def BasicBlock(inputs, filters, stride=1):
    shortcut = inputs

    x = Conv2D(filters, (3, 3), strides=stride, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters, (3, 3), strides=1, padding='same')(x)
    x = BatchNormalization()(x)

    if stride != 1:
        shortcut = Conv2D(filters, (1, 1), strides=stride, padding='same')(inputs)
        shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    
    x = Dropout(0.5)(x) # Dropout = 0.5
    
    return x

# ResNet 정의
def ResNet18():
    inputs = Input(shape=(32, 32, 3))

    x = Conv2D(64, (3, 3), strides=1, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = BasicBlock(x, 64)
    x = BasicBlock(x, 64)
    x = BasicBlock(x, 128, stride=2)
    x = BasicBlock(x, 128)
    x = BasicBlock(x, 256, stride=2)
    x = BasicBlock(x, 256)
    x = BasicBlock(x, 512, stride=2)
    x = BasicBlock(x, 512)

    x = GlobalAveragePooling2D()(x)
    outputs = Dense(10, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# %%
model = ResNet18()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 64)   0           batch_normalization_2[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   36928       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           batch_normalization_4[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  8320        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 128)  0           batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           batch_normalization_9[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 128)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 256)    1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 256)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 256)    590080      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 256)    33024       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 256)    0           batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 256)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 256)    1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           batch_normalization_14[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 256)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 512)    1180160     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 512)    2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 512)    131584      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 512)    0           batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 4, 4, 512)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 512)    2359808     dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 512)    0           batch_normalization_19[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 4, 4, 512)    0           activation_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           dropout_7[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 11,188,362
# Trainable params: 11,178,762
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
# 모델 컴파일
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# 학습 루프, Dropout = 0.5
history = model.fit(x_train, y_train, batch_size=128, epochs=100)
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2f}%")
# Out:
# Epoch 1/100
# 391/391 [==============================] - 51s 115ms/step - loss: 1.7666 - accuracy: 0.3546
# Epoch 2/100
# 391/391 [==============================] - 46s 117ms/step - loss: 1.2992 - accuracy: 0.5261
# Epoch 3/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.0859 - accuracy: 0.6090
# Epoch 4/100
# 391/391 [==============================] - 46s 116ms/step - loss: 0.9489 - accuracy: 0.6628
# Epoch 5/100
# 391/391 [==============================] - 46s 116ms/step - loss: 0.8554 - accuracy: 0.6975
# Epoch 6/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7813 - accuracy: 0.7235
# Epoch 7/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7217 - accuracy: 0.7476
# Epoch 8/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6657 - accuracy: 0.7675
# Epoch 9/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6172 - accuracy: 0.7845
# Epoch 10/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5773 - accuracy: 0.7987
# Epoch 11/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5457 - accuracy: 0.8113
# Epoch 12/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5119 - accuracy: 0.8235
# Epoch 13/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4846 - accuracy: 0.8317
# Epoch 14/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4580 - accuracy: 0.8414
# Epoch 15/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4304 - accuracy: 0.8502
# Epoch 16/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4126 - accuracy: 0.8564
# Epoch 17/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3965 - accuracy: 0.8617
# Epoch 18/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3731 - accuracy: 0.8695
# Epoch 19/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3508 - accuracy: 0.8758
# Epoch 20/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3321 - accuracy: 0.8830
# Epoch 21/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3177 - accuracy: 0.8898
# Epoch 22/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3035 - accuracy: 0.8950
# Epoch 23/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2891 - accuracy: 0.8989
# Epoch 24/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2737 - accuracy: 0.9009
# Epoch 25/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2620 - accuracy: 0.9078
# Epoch 26/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2470 - accuracy: 0.9138
# Epoch 27/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2402 - accuracy: 0.9132
# Epoch 28/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2272 - accuracy: 0.9202
# Epoch 29/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2209 - accuracy: 0.9209
# Epoch 30/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.2067 - accuracy: 0.9265
# Epoch 31/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1991 - accuracy: 0.9301
# Epoch 32/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1874 - accuracy: 0.9337
# Epoch 33/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1801 - accuracy: 0.9352
# Epoch 34/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1769 - accuracy: 0.9368
# Epoch 35/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1635 - accuracy: 0.9424
# Epoch 36/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1618 - accuracy: 0.9429
# Epoch 37/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1511 - accuracy: 0.9455
# Epoch 38/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1415 - accuracy: 0.9503
# Epoch 39/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1389 - accuracy: 0.9502
# Epoch 40/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1334 - accuracy: 0.9519
# Epoch 41/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1298 - accuracy: 0.9539
# Epoch 42/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1199 - accuracy: 0.9569
# Epoch 43/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1200 - accuracy: 0.9565
# Epoch 44/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1146 - accuracy: 0.9588
# Epoch 45/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1115 - accuracy: 0.9608
# Epoch 46/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1079 - accuracy: 0.9611
# Epoch 47/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1069 - accuracy: 0.9617
# Epoch 48/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1003 - accuracy: 0.9644
# Epoch 49/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.1007 - accuracy: 0.9635
# Epoch 50/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0928 - accuracy: 0.9658
# Epoch 51/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0949 - accuracy: 0.9663
# Epoch 52/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0902 - accuracy: 0.9673
# Epoch 53/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0894 - accuracy: 0.9682
# Epoch 54/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0816 - accuracy: 0.9711
# Epoch 55/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0834 - accuracy: 0.9698
# Epoch 56/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0750 - accuracy: 0.9729
# Epoch 57/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0773 - accuracy: 0.9728
# Epoch 58/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0775 - accuracy: 0.9730
# Epoch 59/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0741 - accuracy: 0.9746
# Epoch 60/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0785 - accuracy: 0.9727
# Epoch 61/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0727 - accuracy: 0.9735
# Epoch 62/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0702 - accuracy: 0.9746
# Epoch 63/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0697 - accuracy: 0.9745
# Epoch 64/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0651 - accuracy: 0.9772
# Epoch 65/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0627 - accuracy: 0.9782
# Epoch 66/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0634 - accuracy: 0.9776
# Epoch 67/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0610 - accuracy: 0.9790
# Epoch 68/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0657 - accuracy: 0.9769
# Epoch 69/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0620 - accuracy: 0.9786
# Epoch 70/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0601 - accuracy: 0.9785
# Epoch 71/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0572 - accuracy: 0.9801
# Epoch 72/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0574 - accuracy: 0.9800
# Epoch 73/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0581 - accuracy: 0.9795
# Epoch 74/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0550 - accuracy: 0.9803
# Epoch 75/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0547 - accuracy: 0.9805
# Epoch 76/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0534 - accuracy: 0.9813
# Epoch 77/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0553 - accuracy: 0.9800
# Epoch 78/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0520 - accuracy: 0.9820
# Epoch 79/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0517 - accuracy: 0.9823
# Epoch 80/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0476 - accuracy: 0.9832
# Epoch 81/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0513 - accuracy: 0.9823
# Epoch 82/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0503 - accuracy: 0.9830
# Epoch 83/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0507 - accuracy: 0.9824
# Epoch 84/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0467 - accuracy: 0.9843
# Epoch 85/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0482 - accuracy: 0.9828
# Epoch 86/100
# 391/391 [==============================] - 46s 116ms/step - loss: 0.0474 - accuracy: 0.9833
# Epoch 87/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0457 - accuracy: 0.9844
# Epoch 88/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0430 - accuracy: 0.9845
# Epoch 89/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0448 - accuracy: 0.9840
# Epoch 90/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0434 - accuracy: 0.9854
# Epoch 91/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0413 - accuracy: 0.9857
# Epoch 92/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0476 - accuracy: 0.9837
# Epoch 93/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0415 - accuracy: 0.9864
# Epoch 94/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0417 - accuracy: 0.9863
# Epoch 95/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0394 - accuracy: 0.9864
# Epoch 96/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0374 - accuracy: 0.9873
# Epoch 97/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0395 - accuracy: 0.9860
# Epoch 98/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0403 - accuracy: 0.9861
# Epoch 99/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0433 - accuracy: 0.9851
# Epoch 100/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.0398 - accuracy: 0.9862
# 313/313 [==============================] - 4s 12ms/step - loss: 0.9054 - accuracy: 0.8308
# Test Loss: 0.9054
# Test Accuracy: 0.83%

# %%
# 학습 결과 시각화
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss over Epochs")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training Accuracy over Epochs")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 컨퓨전 매트릭스 생성
y_pred = model.predict(x_test)
y_pred_classes = tf.argmax(y_pred, axis=1)
confusion_mtx = confusion_matrix(y_test, y_pred_classes)

# 컨퓨전 매트릭스 시각화
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# 모델이 "비행기(airplane)"로 예측한 인덱스 찾기
misclassified_as_airplane_idx = np.where(y_pred_classes == 0)[0]

# 실제 값이 "새(bird)"인 인덱스만 필터링
misclassified_bird_as_airplane_idx = [idx for idx in misclassified_as_airplane_idx if y_test[idx] == 2]

# 랜덤하게 5개의 인덱스 선택
random_misclassified_idx = np.random.choice(misclassified_bird_as_airplane_idx, 5, replace=False)

# 랜덤으로 선택한 오분류된 이미지 시각화
plt.figure(figsize=(15, 5))
for i, idx in enumerate(random_misclassified_idx):
    plt.subplot(1, 5, i + 1)
    plt.imshow(x_test[idx].reshape(32, 32, 3), cmap='gray')
    true_label = class_names[y_test[idx][0]]
    predicted_label = class_names[y_pred_classes[idx]]
    plt.title(f"True: {true_label}\nPredicted: {predicted_label}")
    plt.axis('off')

plt.tight_layout()
plt.show()
