# %%
# !nvidia-smi
# Out:
# Wed Aug 30 04:39:05 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.182.03   Driver Version: 470.182.03   CUDA Version: 11.4     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P0    30W /  70W |   5100MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
import tensorflow as tf
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np

# 데이터 로딩 및 전처리
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# 클래스 이름 정의
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# BasicBlock 정의
def BasicBlock(inputs, filters, stride=1):
    shortcut = inputs

    x = Conv2D(filters, (3, 3), strides=stride, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters, (3, 3), strides=1, padding='same')(x)
    x = BatchNormalization()(x)

    if stride != 1:
        shortcut = Conv2D(filters, (1, 1), strides=stride, padding='same')(inputs)
        shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    
    x = Dropout(0.8)(x) # Dropout = 0.8
    
    return x

# ResNet 정의
def ResNet18():
    inputs = Input(shape=(32, 32, 3))

    x = Conv2D(64, (3, 3), strides=1, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = BasicBlock(x, 64)
    x = BasicBlock(x, 64)
    x = BasicBlock(x, 128, stride=2)
    x = BasicBlock(x, 128)
    x = BasicBlock(x, 256, stride=2)
    x = BasicBlock(x, 256)
    x = BasicBlock(x, 512, stride=2)
    x = BasicBlock(x, 512)

    x = GlobalAveragePooling2D()(x)
    outputs = Dense(10, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# %%
model = ResNet18()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 64)   0           batch_normalization_2[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   36928       dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           batch_normalization_4[0][0]
#                                                                  dropout[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 32, 32, 64)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 128)  73856       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  8320        dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 128)  0           batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 16, 16, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  147584      dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           batch_normalization_9[0][0]
#                                                                  dropout_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 16, 16, 128)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 256)    1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 256)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 256)    590080      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 256)    33024       dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 256)    0           batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 8, 8, 256)    0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    590080      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 256)    1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           batch_normalization_14[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 256)    0           activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 512)    1180160     dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 512)    2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 512)    131584      dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 512)    0           batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 4, 4, 512)    0           activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 512)    2359808     dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 512)    0           batch_normalization_19[0][0]
#                                                                  dropout_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 4, 4, 512)    0           activation_16[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           dropout_7[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 11,188,362
# Trainable params: 11,178,762
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
# 모델 컴파일
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# 학습 루프, Dropout = 0.8
history = model.fit(x_train, y_train, batch_size=128, epochs=100)
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_acc:.2f}%")
# Out:
# Epoch 1/100
# 391/391 [==============================] - 52s 118ms/step - loss: 2.3588 - accuracy: 0.1920
# Epoch 2/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.9542 - accuracy: 0.2522
# Epoch 3/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.8097 - accuracy: 0.3099
# Epoch 4/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.6882 - accuracy: 0.3565
# Epoch 5/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.5956 - accuracy: 0.3982
# Epoch 6/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.4791 - accuracy: 0.4453
# Epoch 7/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.3748 - accuracy: 0.4899
# Epoch 8/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.2879 - accuracy: 0.5229
# Epoch 9/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.2220 - accuracy: 0.5489
# Epoch 10/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.1626 - accuracy: 0.5786
# Epoch 11/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.1046 - accuracy: 0.5977
# Epoch 12/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.0581 - accuracy: 0.6191
# Epoch 13/100
# 391/391 [==============================] - 45s 116ms/step - loss: 1.0243 - accuracy: 0.6313
# Epoch 14/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.9915 - accuracy: 0.6436
# Epoch 15/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.9646 - accuracy: 0.6535
# Epoch 16/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.9447 - accuracy: 0.6623
# Epoch 17/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.9204 - accuracy: 0.6700
# Epoch 18/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.9004 - accuracy: 0.6796
# Epoch 19/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.8793 - accuracy: 0.6871
# Epoch 20/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.8587 - accuracy: 0.6940
# Epoch 21/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.8452 - accuracy: 0.6994
# Epoch 22/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.8266 - accuracy: 0.7057
# Epoch 23/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.8126 - accuracy: 0.7125
# Epoch 24/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.8021 - accuracy: 0.7166
# Epoch 25/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7879 - accuracy: 0.7215
# Epoch 26/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7679 - accuracy: 0.7286
# Epoch 27/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7570 - accuracy: 0.7328
# Epoch 28/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7473 - accuracy: 0.7376
# Epoch 29/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7372 - accuracy: 0.7398
# Epoch 30/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7251 - accuracy: 0.7437
# Epoch 31/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7170 - accuracy: 0.7474
# Epoch 32/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.7032 - accuracy: 0.7534
# Epoch 33/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6941 - accuracy: 0.7575
# Epoch 34/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6823 - accuracy: 0.7581
# Epoch 35/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6717 - accuracy: 0.7645
# Epoch 36/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6730 - accuracy: 0.7638
# Epoch 37/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6602 - accuracy: 0.7674
# Epoch 38/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6499 - accuracy: 0.7730
# Epoch 39/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6431 - accuracy: 0.7741
# Epoch 40/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6405 - accuracy: 0.7754
# Epoch 41/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6242 - accuracy: 0.7805
# Epoch 42/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6182 - accuracy: 0.7841
# Epoch 43/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6102 - accuracy: 0.7862
# Epoch 44/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.6136 - accuracy: 0.7846
# Epoch 45/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5954 - accuracy: 0.7921
# Epoch 46/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5985 - accuracy: 0.7921
# Epoch 47/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5860 - accuracy: 0.7939
# Epoch 48/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5795 - accuracy: 0.7969
# Epoch 49/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5756 - accuracy: 0.7996
# Epoch 50/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5703 - accuracy: 0.8017
# Epoch 51/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5651 - accuracy: 0.8019
# Epoch 52/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5577 - accuracy: 0.8050
# Epoch 53/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5500 - accuracy: 0.8083
# Epoch 54/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5428 - accuracy: 0.8097
# Epoch 55/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5458 - accuracy: 0.8083
# Epoch 56/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5355 - accuracy: 0.8140
# Epoch 57/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5307 - accuracy: 0.8143
# Epoch 58/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5307 - accuracy: 0.8118
# Epoch 59/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5261 - accuracy: 0.8163
# Epoch 60/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5240 - accuracy: 0.8166
# Epoch 61/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5217 - accuracy: 0.8182
# Epoch 62/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5094 - accuracy: 0.8216
# Epoch 63/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5103 - accuracy: 0.8216
# Epoch 64/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.5050 - accuracy: 0.8251
# Epoch 65/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4993 - accuracy: 0.8257
# Epoch 66/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4944 - accuracy: 0.8289
# Epoch 67/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4981 - accuracy: 0.8255
# Epoch 68/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4872 - accuracy: 0.8309
# Epoch 69/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4874 - accuracy: 0.8327
# Epoch 70/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4834 - accuracy: 0.8308
# Epoch 71/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4762 - accuracy: 0.8336
# Epoch 72/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4726 - accuracy: 0.8370
# Epoch 73/100
# 391/391 [==============================] - 45s 115ms/step - loss: 0.4693 - accuracy: 0.8392
# Epoch 74/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4660 - accuracy: 0.8371
# Epoch 75/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4665 - accuracy: 0.8378
# Epoch 76/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4630 - accuracy: 0.8407
# Epoch 77/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4586 - accuracy: 0.8405
# Epoch 78/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4588 - accuracy: 0.8400
# Epoch 79/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4535 - accuracy: 0.8420
# Epoch 80/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4488 - accuracy: 0.8436
# Epoch 81/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4499 - accuracy: 0.8440
# Epoch 82/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4402 - accuracy: 0.8461
# Epoch 83/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4400 - accuracy: 0.8463
# Epoch 84/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4359 - accuracy: 0.8473
# Epoch 85/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4357 - accuracy: 0.8482
# Epoch 86/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4313 - accuracy: 0.8484
# Epoch 87/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4292 - accuracy: 0.8491
# Epoch 88/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4329 - accuracy: 0.8499
# Epoch 89/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4253 - accuracy: 0.8499
# Epoch 90/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4228 - accuracy: 0.8523
# Epoch 91/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4208 - accuracy: 0.8521
# Epoch 92/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4196 - accuracy: 0.8531
# Epoch 93/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4183 - accuracy: 0.8548
# Epoch 94/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4157 - accuracy: 0.8548
# Epoch 95/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4094 - accuracy: 0.8576
# Epoch 96/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4068 - accuracy: 0.8571
# Epoch 97/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4057 - accuracy: 0.8595
# Epoch 98/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4044 - accuracy: 0.8587
# Epoch 99/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.3995 - accuracy: 0.8606
# Epoch 100/100
# 391/391 [==============================] - 45s 116ms/step - loss: 0.4003 - accuracy: 0.8601
# 313/313 [==============================] - 4s 12ms/step - loss: 0.6566 - accuracy: 0.7905
# Test Loss: 0.6566
# Test Accuracy: 0.79%

# %%
# 학습 결과 시각화
plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="Training Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training Loss over Epochs")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training Accuracy over Epochs")
plt.legend()

plt.tight_layout()
plt.show()

# %%
# 컨퓨전 매트릭스 생성
y_pred = model.predict(x_test)
y_pred_classes = tf.argmax(y_pred, axis=1)
confusion_mtx = confusion_matrix(y_test, y_pred_classes)

# 컨퓨전 매트릭스 시각화
import seaborn as sns
plt.figure(figsize=(8, 6))
sns.heatmap(confusion_mtx, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# 모델이 "고양이(cat)"로 예측한 인덱스 찾기
misclassified_as_cat_idx = np.where(y_pred_classes == 3)[0]

# 실제 값이 "개(dog)"인 인덱스만 필터링
misclassified_dog_as_cat_idx = [idx for idx in misclassified_as_cat_idx if y_test[idx] == 5]

# 랜덤하게 5개의 인덱스 선택
random_misclassified_idx = np.random.choice(misclassified_dog_as_cat_idx, 5, replace=False)

# 랜덤으로 선택한 오분류된 이미지 시각화
plt.figure(figsize=(15, 5))
for i, idx in enumerate(random_misclassified_idx):
    plt.subplot(1, 5, i + 1)
    plt.imshow(x_test[idx].reshape(32, 32, 3), cmap='gray')
    true_label = class_names[y_test[idx][0]]
    predicted_label = class_names[y_pred_classes[idx]]
    plt.title(f"True: {true_label}\nPredicted: {predicted_label}")
    plt.axis('off')

plt.tight_layout()
plt.show()
