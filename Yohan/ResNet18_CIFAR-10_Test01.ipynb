# %%
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, GlobalAveragePooling2D, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import LearningRateScheduler, Callback
import matplotlib.pyplot as plt

# 데이터 로딩 및 전처리
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
import tensorflow_addons as tfa

def augment(image, label):
    image = tf.image.random_flip_left_right(image)
    angle = tf.random.uniform([], -0.2, 0.2)  # 랜덤 각도 생성
    image = tfa.image.rotate(image, angle)
    return image, label

def prepare_for_training(ds, shuffle_buffer_size=1000, BATCH_SIZE=32, AUTOTUNE=tf.data.AUTOTUNE):
    ds = ds.map(augment, num_parallel_calls=2) 
    ds = ds.shuffle(buffer_size=shuffle_buffer_size) 
    ds = ds.repeat() 
    ds = ds.batch(32) 
    ds = ds.prefetch(buffer_size=AUTOTUNE) 
    return ds


(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()
train_ds = tf.data.Dataset.from_tensor_slices((x_train, y_train))
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# 데이터 파이프라인 준비
train_ds = prepare_for_training(train_ds)

# %%
augmented_images, augmented_labels = next(iter(train_ds))

# 이미지를 시각화
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(augmented_images[i].numpy())
    plt.xlabel(str(augmented_labels[i].numpy()[0]))  # [0]을 추가하여 2D 배열에서 값을 추출합니다.
plt.show()

# %%
# BasicBlock 정의
def BasicBlock(inputs, filters, stride=1):
    shortcut = inputs

    x = Conv2D(filters, (3, 3), strides=stride, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = Conv2D(filters, (3, 3), strides=1, padding='same')(x)
    x = BatchNormalization()(x)

    if stride != 1:
        shortcut = Conv2D(filters, (1, 1), strides=stride, padding='same')(inputs)
        shortcut = BatchNormalization()(shortcut)

    x = Add()([x, shortcut])
    x = Activation('relu')(x)
    return x

# ResNet 정의
def ResNet18():
    inputs = Input(shape=(32, 32, 3))

    x = Conv2D(64, (3, 3), strides=1, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    x = BasicBlock(x, 64)
    x = BasicBlock(x, 64)
    x = BasicBlock(x, 128, stride=2)
    x = BasicBlock(x, 128)
    x = BasicBlock(x, 256, stride=2)
    x = BasicBlock(x, 256)
    x = BasicBlock(x, 512, stride=2)
    x = BasicBlock(x, 512)

    x = GlobalAveragePooling2D()(x)
    outputs = Dense(10, activation='softmax')(x)

    model = Model(inputs, outputs)
    return model

# %%
model = ResNet18()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 32, 32, 64)   1792        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 32, 32, 64)   256         conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 32, 32, 64)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 64)   36928       activation[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 64)   256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 64)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 32, 32, 64)   36928       activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 32, 32, 64)   256         conv2d_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 32, 32, 64)   0           batch_normalization_2[0][0]
#                                                                  activation[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 32, 32, 64)   0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 32, 32, 64)   36928       activation_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 64)   256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 64)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 32, 32, 64)   36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 32, 32, 64)   256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 32, 32, 64)   0           batch_normalization_4[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 32, 32, 64)   0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 16, 16, 128)  73856       activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 16, 16, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 16, 16, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 16, 16, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 16, 16, 128)  8320        activation_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 16, 16, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 16, 16, 128)  512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 16, 16, 128)  0           batch_normalization_6[0][0]
#                                                                  batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 16, 16, 128)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 128)  147584      activation_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 16, 16, 128)  512         conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 16, 16, 128)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  147584      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 16, 16, 128)  512         conv2d_9[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 16, 16, 128)  0           batch_normalization_9[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 16, 16, 128)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 8, 8, 256)    295168      activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 8, 8, 256)    1024        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 8, 8, 256)    0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 8, 8, 256)    590080      activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 8, 8, 256)    33024       activation_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 8, 8, 256)    1024        conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 8, 8, 256)    1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 8, 8, 256)    0           batch_normalization_11[0][0]
#                                                                  batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 8, 8, 256)    0           add_4[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 256)    590080      activation_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 256)    1024        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 8, 8, 256)    0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 256)    590080      activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 8, 8, 256)    1024        conv2d_14[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 8, 8, 256)    0           batch_normalization_14[0][0]
#                                                                  activation_10[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 8, 8, 256)    0           add_5[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 4, 4, 512)    1180160     activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 4, 4, 512)    2048        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 4, 4, 512)    0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 4, 4, 512)    2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 512)    131584      activation_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 4, 4, 512)    2048        conv2d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 4, 4, 512)    2048        conv2d_17[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 4, 4, 512)    0           batch_normalization_16[0][0]
#                                                                  batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 512)    0           add_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 4, 4, 512)    2359808     activation_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 4, 4, 512)    2048        conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 4, 4, 512)    0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 512)    2359808     activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 4, 4, 512)    2048        conv2d_19[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 4, 4, 512)    0           batch_normalization_19[0][0]
#                                                                  activation_14[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 4, 4, 512)    0           add_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d (Globa (None, 512)          0           activation_16[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 10)           5130        global_average_pooling2d[0][0]
# ==================================================================================================
# Total params: 11,188,362
# Trainable params: 11,178,762
# Non-trainable params: 9,600
# __________________________________________________________________________________________________

# %%
plot_model(model, to_file='resnet18.png', show_shapes=True, show_layer_names=True)

# %%
# 학습률 기록 콜백 정의
class LearningRateLogger(Callback):
    def on_epoch_end(self, epoch, logs=None):
        print(f"\nLearning Rate for Epoch {epoch+1}: {self.model.optimizer.lr.numpy()}")

# %%
# 모델 컴파일
model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# 학습률 스케줄러 정의
def lr_schedule(epoch):
    if epoch < 50:
        lr = 0.001
    elif epoch < 75:
        lr = 0.0005
    else:
        lr = 0.0001
    return lr

lr_scheduler = LearningRateScheduler(lr_schedule)

# %%
# 학습률 기록 콜백 생성
lr_logger = LearningRateLogger()

# %%
# 학습 루프
num_epochs = 100

early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10, verbose=1, restore_best_weights=True)

# steps_per_epoch를 설정합니다. 
steps_per_epoch = len(x_train) // 32

# 학습을 수행합니다.
history = model.fit(train_ds, 
                    epochs=num_epochs,
                    steps_per_epoch=steps_per_epoch, 
                    callbacks=[lr_scheduler, lr_logger, early_stop])
# Out:
# Epoch 1/100
# 1562/1562 [==============================] - 66s 39ms/step - loss: 1.3163 - accuracy: 0.5301
#
# Learning Rate for Epoch 1: 0.0010000000474974513
# Epoch 2/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.8632 - accuracy: 0.6963
#
# Learning Rate for Epoch 2: 0.0010000000474974513
# Epoch 3/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.7043 - accuracy: 0.7539
#
# Learning Rate for Epoch 3: 0.0010000000474974513
# Epoch 4/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.6017 - accuracy: 0.7923
#
# Learning Rate for Epoch 4: 0.0010000000474974513
# Epoch 5/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.5255 - accuracy: 0.8184
#
# Learning Rate for Epoch 5: 0.0010000000474974513
# Epoch 6/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4607 - accuracy: 0.8404
#
# Learning Rate for Epoch 6: 0.0010000000474974513
# Epoch 7/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.4106 - accuracy: 0.8558
#
# Learning Rate for Epoch 7: 0.0010000000474974513
# Epoch 8/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.3640 - accuracy: 0.8737
#
# Learning Rate for Epoch 8: 0.0010000000474974513
# Epoch 9/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.3228 - accuracy: 0.8875
#
# Learning Rate for Epoch 9: 0.0010000000474974513
# Epoch 10/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2919 - accuracy: 0.8981
#
# Learning Rate for Epoch 10: 0.0010000000474974513
# Epoch 11/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2632 - accuracy: 0.9082
#
# Learning Rate for Epoch 11: 0.0010000000474974513
# Epoch 12/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2354 - accuracy: 0.9184
#
# Learning Rate for Epoch 12: 0.0010000000474974513
# Epoch 13/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.2109 - accuracy: 0.9260
#
# Learning Rate for Epoch 13: 0.0010000000474974513
# Epoch 14/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1933 - accuracy: 0.9326
#
# Learning Rate for Epoch 14: 0.0010000000474974513
# Epoch 15/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1754 - accuracy: 0.9392
#
# Learning Rate for Epoch 15: 0.0010000000474974513
# Epoch 16/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1626 - accuracy: 0.9435
#
# Learning Rate for Epoch 16: 0.0010000000474974513
# Epoch 17/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1451 - accuracy: 0.9483
#
# Learning Rate for Epoch 17: 0.0010000000474974513
# Epoch 18/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1353 - accuracy: 0.9529
#
# Learning Rate for Epoch 18: 0.0010000000474974513
# Epoch 19/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1265 - accuracy: 0.9550
#
# Learning Rate for Epoch 19: 0.0010000000474974513
# Epoch 20/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1168 - accuracy: 0.9594
#
# Learning Rate for Epoch 20: 0.0010000000474974513
# Epoch 21/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1064 - accuracy: 0.9626
#
# Learning Rate for Epoch 21: 0.0010000000474974513
# Epoch 22/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.1029 - accuracy: 0.9638
#
# Learning Rate for Epoch 22: 0.0010000000474974513
# Epoch 23/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0942 - accuracy: 0.9673
#
# Learning Rate for Epoch 23: 0.0010000000474974513
# Epoch 24/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0897 - accuracy: 0.9686
#
# Learning Rate for Epoch 24: 0.0010000000474974513
# Epoch 25/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0828 - accuracy: 0.9715
#
# Learning Rate for Epoch 25: 0.0010000000474974513
# Epoch 26/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0831 - accuracy: 0.9709
#
# Learning Rate for Epoch 26: 0.0010000000474974513
# Epoch 27/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0738 - accuracy: 0.9744
#
# Learning Rate for Epoch 27: 0.0010000000474974513
# Epoch 28/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0763 - accuracy: 0.9742
#
# Learning Rate for Epoch 28: 0.0010000000474974513
# Epoch 29/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0684 - accuracy: 0.9761
#
# Learning Rate for Epoch 29: 0.0010000000474974513
# Epoch 30/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0689 - accuracy: 0.9757
#
# Learning Rate for Epoch 30: 0.0010000000474974513
# Epoch 31/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0656 - accuracy: 0.9768
#
# Learning Rate for Epoch 31: 0.0010000000474974513
# Epoch 32/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0585 - accuracy: 0.9801
#
# Learning Rate for Epoch 32: 0.0010000000474974513
# Epoch 33/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0610 - accuracy: 0.9793
#
# Learning Rate for Epoch 33: 0.0010000000474974513
# Epoch 34/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0595 - accuracy: 0.9806
#
# Learning Rate for Epoch 34: 0.0010000000474974513
# Epoch 35/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0537 - accuracy: 0.9813
#
# Learning Rate for Epoch 35: 0.0010000000474974513
# Epoch 36/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0525 - accuracy: 0.9812
#
# Learning Rate for Epoch 36: 0.0010000000474974513
# Epoch 37/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0556 - accuracy: 0.9808
#
# Learning Rate for Epoch 37: 0.0010000000474974513
# Epoch 38/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0478 - accuracy: 0.9842
#
# Learning Rate for Epoch 38: 0.0010000000474974513
# Epoch 39/100
# 1562/1562 [==============================] - 60s 38ms/step - loss: 0.0480 - accuracy: 0.9837
#
# Learning Rate for Epoch 39: 0.0010000000474974513
# Epoch 40/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0459 - accuracy: 0.9840
#
# Learning Rate for Epoch 40: 0.0010000000474974513
# Epoch 41/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0448 - accuracy: 0.9847
#
# Learning Rate for Epoch 41: 0.0010000000474974513
# Epoch 42/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0451 - accuracy: 0.9849
#
# Learning Rate for Epoch 42: 0.0010000000474974513
# Epoch 43/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0430 - accuracy: 0.9848
#
# Learning Rate for Epoch 43: 0.0010000000474974513
# Epoch 44/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0443 - accuracy: 0.9847
#
# Learning Rate for Epoch 44: 0.0010000000474974513
# Epoch 45/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0395 - accuracy: 0.9867
#
# Learning Rate for Epoch 45: 0.0010000000474974513
# Epoch 46/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0398 - accuracy: 0.9866
#
# Learning Rate for Epoch 46: 0.0010000000474974513
# Epoch 47/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0378 - accuracy: 0.9874
#
# Learning Rate for Epoch 47: 0.0010000000474974513
# Epoch 48/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0397 - accuracy: 0.9861
#
# Learning Rate for Epoch 48: 0.0010000000474974513
# Epoch 49/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0357 - accuracy: 0.9879
#
# Learning Rate for Epoch 49: 0.0010000000474974513
# Epoch 50/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0358 - accuracy: 0.9881
#
# Learning Rate for Epoch 50: 0.0010000000474974513
# Epoch 51/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0207 - accuracy: 0.9929
#
# Learning Rate for Epoch 51: 0.0005000000237487257
# Epoch 52/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0151 - accuracy: 0.9953
#
# Learning Rate for Epoch 52: 0.0005000000237487257
# Epoch 53/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0147 - accuracy: 0.9951
#
# Learning Rate for Epoch 53: 0.0005000000237487257
# Epoch 54/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0138 - accuracy: 0.9950
#
# Learning Rate for Epoch 54: 0.0005000000237487257
# Epoch 55/100
# 1562/1562 [==============================] - 60s 38ms/step - loss: 0.0157 - accuracy: 0.9948
#
# Learning Rate for Epoch 55: 0.0005000000237487257
# Epoch 56/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0140 - accuracy: 0.9957
#
# Learning Rate for Epoch 56: 0.0005000000237487257
# Epoch 57/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0127 - accuracy: 0.9956
#
# Learning Rate for Epoch 57: 0.0005000000237487257
# Epoch 58/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0129 - accuracy: 0.9956
#
# Learning Rate for Epoch 58: 0.0005000000237487257
# Epoch 59/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0127 - accuracy: 0.9959
#
# Learning Rate for Epoch 59: 0.0005000000237487257
# Epoch 60/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0122 - accuracy: 0.9958
#
# Learning Rate for Epoch 60: 0.0005000000237487257
# Epoch 61/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0113 - accuracy: 0.9960
#
# Learning Rate for Epoch 61: 0.0005000000237487257
# Epoch 62/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0124 - accuracy: 0.9959
#
# Learning Rate for Epoch 62: 0.0005000000237487257
# Epoch 63/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0117 - accuracy: 0.9962
#
# Learning Rate for Epoch 63: 0.0005000000237487257
# Epoch 64/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0108 - accuracy: 0.9965
#
# Learning Rate for Epoch 64: 0.0005000000237487257
# Epoch 65/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0115 - accuracy: 0.9959
#
# Learning Rate for Epoch 65: 0.0005000000237487257
# Epoch 66/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0109 - accuracy: 0.9961
#
# Learning Rate for Epoch 66: 0.0005000000237487257
# Epoch 67/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0093 - accuracy: 0.9969
#
# Learning Rate for Epoch 67: 0.0005000000237487257
# Epoch 68/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0118 - accuracy: 0.9961
#
# Learning Rate for Epoch 68: 0.0005000000237487257
# Epoch 69/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0102 - accuracy: 0.9966
#
# Learning Rate for Epoch 69: 0.0005000000237487257
# Epoch 70/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0095 - accuracy: 0.9967
#
# Learning Rate for Epoch 70: 0.0005000000237487257
# Epoch 71/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0109 - accuracy: 0.9966
#
# Learning Rate for Epoch 71: 0.0005000000237487257
# Epoch 72/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0092 - accuracy: 0.9967
#
# Learning Rate for Epoch 72: 0.0005000000237487257
# Epoch 73/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0107 - accuracy: 0.9968
#
# Learning Rate for Epoch 73: 0.0005000000237487257
# Epoch 74/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0104 - accuracy: 0.9961
#
# Learning Rate for Epoch 74: 0.0005000000237487257
# Epoch 75/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0091 - accuracy: 0.9968
#
# Learning Rate for Epoch 75: 0.0005000000237487257
# Epoch 76/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0069 - accuracy: 0.9978
#
# Learning Rate for Epoch 76: 9.999999747378752e-05
# Epoch 77/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0041 - accuracy: 0.9988
#
# Learning Rate for Epoch 77: 9.999999747378752e-05
# Epoch 78/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0037 - accuracy: 0.9988
#
# Learning Rate for Epoch 78: 9.999999747378752e-05
# Epoch 79/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0030 - accuracy: 0.9992
#
# Learning Rate for Epoch 79: 9.999999747378752e-05
# Epoch 80/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0030 - accuracy: 0.9991
#
# Learning Rate for Epoch 80: 9.999999747378752e-05
# Epoch 81/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0030 - accuracy: 0.9990
#
# Learning Rate for Epoch 81: 9.999999747378752e-05
# Epoch 82/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0029 - accuracy: 0.9991
#
# Learning Rate for Epoch 82: 9.999999747378752e-05
# Epoch 83/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0018 - accuracy: 0.9994
#
# Learning Rate for Epoch 83: 9.999999747378752e-05
# Epoch 84/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0023 - accuracy: 0.9993
#
# Learning Rate for Epoch 84: 9.999999747378752e-05
# Epoch 85/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0024 - accuracy: 0.9993
#
# Learning Rate for Epoch 85: 9.999999747378752e-05
# Epoch 86/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0023 - accuracy: 0.9994
#
# Learning Rate for Epoch 86: 9.999999747378752e-05
# Epoch 87/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0024 - accuracy: 0.9991
#
# Learning Rate for Epoch 87: 9.999999747378752e-05
# Epoch 88/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0016 - accuracy: 0.9995
#
# Learning Rate for Epoch 88: 9.999999747378752e-05
# Epoch 89/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0020 - accuracy: 0.9993
#
# Learning Rate for Epoch 89: 9.999999747378752e-05
# Epoch 90/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0015 - accuracy: 0.9996
#
# Learning Rate for Epoch 90: 9.999999747378752e-05
# Epoch 91/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0014 - accuracy: 0.9996
#
# Learning Rate for Epoch 91: 9.999999747378752e-05
# Epoch 92/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0017 - accuracy: 0.9996
#
# Learning Rate for Epoch 92: 9.999999747378752e-05
# Epoch 93/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0014 - accuracy: 0.9996
#
# Learning Rate for Epoch 93: 9.999999747378752e-05
# Epoch 94/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0013 - accuracy: 0.9996
#
# Learning Rate for Epoch 94: 9.999999747378752e-05
# Epoch 95/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 8.7128e-04 - accuracy: 0.9997
#
# Learning Rate for Epoch 95: 9.999999747378752e-05
# Epoch 96/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0014 - accuracy: 0.9996
#
# Learning Rate for Epoch 96: 9.999999747378752e-05
# Epoch 97/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0011 - accuracy: 0.9997
#
# Learning Rate for Epoch 97: 9.999999747378752e-05
# Epoch 98/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0011 - accuracy: 0.9997
#
# Learning Rate for Epoch 98: 9.999999747378752e-05
# Epoch 99/100
# 1562/1562 [==============================] - 61s 39ms/step - loss: 0.0012 - accuracy: 0.9996
#
# Learning Rate for Epoch 99: 9.999999747378752e-05
# Epoch 100/100
# 1562/1562 [==============================] - 60s 39ms/step - loss: 0.0013 - accuracy: 0.9995
#
# Learning Rate for Epoch 100: 9.999999747378752e-05

# %%
#모델 평가
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f"Test accuracy: {test_acc * 100:.2f}%")
# Out:
# 313/313 - 4s - loss: 0.5253 - accuracy: 0.9162
# Test accuracy: 91.62%

# %%
plt.figure(figsize=(10, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Train Accuracy', color='orange')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Accuracy over Epochs')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns

class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# 모델을 사용하여 예측 수행
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = y_test

# 컨퓨전 매트릭스 생성
cm = confusion_matrix(y_true, y_pred_classes)

# 컨퓨전 매트릭스 시각화
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
# 모델을 사용하여 예측 수행
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = y_test.squeeze()

# "개"를 예측했는데 실제로는 "고양이"인 경우와 "고양이"를 예측했는데 실제로는 "개"인 경우의 인덱스를 찾습니다.
misclassified_as_dog = np.where((y_true == 3) & (y_pred_classes == 5))[0]
misclassified_as_cat = np.where((y_true == 5) & (y_pred_classes == 3))[0]

# 두 경우를 합쳐서 전체 잘못 분류된 인덱스를 얻습니다.
total_misclassified = np.concatenate([misclassified_as_dog, misclassified_as_cat])

# 잘못 분류된 인덱스 중에서 무작위로 5개를 선택합니다.
selected_idx = np.random.choice(total_misclassified, 5, replace=False)

# 시각화
plt.figure(figsize=(15, 5))

for i, idx in enumerate(selected_idx):
    plt.subplot(1, 5, i+1)
    plt.imshow(x_test[idx], cmap='gray')  # 'cmap' 파라미터는 필요에 따라 제거할 수 있습니다.
    plt.title(f"True: {class_names[y_true[idx]]}\nPredicted: {class_names[y_pred_classes[idx]]}")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
selected_idx = np.random.choice(total_misclassified, 5, replace=False)

# 시각화
plt.figure(figsize=(15, 5))

for i, idx in enumerate(selected_idx):
    plt.subplot(1, 5, i+1)
    plt.imshow(x_test[idx], cmap='gray')  # 'cmap' 파라미터는 필요에 따라 제거할 수 있습니다.
    plt.title(f"True: {class_names[y_true[idx]]}\nPredicted: {class_names[y_pred_classes[idx]]}")
    plt.axis('off')

plt.tight_layout()
plt.show()
